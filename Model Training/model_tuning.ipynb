# %%
from ultralytics import YOLO, settings

# %%
# Define custom search space
hyp = {
    "lr0": (1e-5, 1e-1),
    "lrf": (0.0001, 0.1),
    "warmup_epochs": (0.0, 5.0),
    "dfl": (0.4, 6.0),
    "hsv_s": (0.0, 0.9),
    "translate": (0.0, 0.9)
}

# %%
# Initialize model
model = YOLO('yolov8n.pt')

# Update directory settings to allow datset to load in properly
directory = "/home/garrett/Desktop/Workspace/NSIN_Sm_24/Model Optimization" # Insert location of local dataset here
settings.update({"datasets_dir": directory})
settings.update({"tensorboard": True}) # Enable tensorboard logging

# Tune model
model.tune(data="./datasets/RGB_and_IR/data.yaml", epochs=150, iterations=75, optimizer="AdamW", plots=False, save=False, val=False, hyp=hyp)
# Out:
# Tuner: Initialized Tuner instance with 'tune_dir=runs/detect/tune'
# Tuner: 💡 Learn about tuning at https://docs.ultralytics.com/guides/hyperparameter-tuning
# Tuner: Starting iteration 1/300 with hyperparameters: {'lr0': 0.01, 'lrf': 0.01, 'momentum': 0.937, 'weight_decay': 0.0005, 'warmup_epochs': 3.0, 'warmup_momentum': 0.8, 'box': 7.5, 'cls': 0.5, 'dfl': 1.5, 'hsv_h': 0.015, 'hsv_s': 0.7, 'hsv_v': 0.4, 'degrees': 0.0, 'translate': 0.1, 'scale': 0.5, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.5, 'bgr': 0.0, 'mosaic': 1.0, 'mixup': 0.0, 'copy_paste': 0.0}
# New https://pypi.org/project/ultralytics/8.2.35 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.32 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (NVIDIA RTX 4000 Ada Generation Laptop GPU, 11911MiB)
# engine/trainer: task=detect, mode=train, model=yolov8n.pt, data=./datasets/RGB_and_IR/data.yaml, epochs=30, time=None, patience=100, batch=16, imgsz=640, save=False, save_period=-1, cache=False, device=None, workers=8, project=None, name=train, exist_ok=False, pretrained=True, optimizer=AdamW, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=False, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=False, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/train
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    751507  ultralytics.nn.modules.head.Detect           [1, [64, 128, 256]]
# Model summary: 225 layers, 3011043 parameters, 3011027 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# ClearML Task: created new task id=20eefa8b07a445769ed68d0f5c9eafda
# 2024-06-18 10:20:22,292 - clearml.Task - INFO - No repository found, storing script code instead
# ClearML results page: https://app.clear.ml/projects/1bf4b4ada375438ebdd6797d9048296d/experiments/20eefa8b07a445769ed68d0f5c9eafda/output/log
# ClearML Initialized a new task. If you want to run remotely, please add clearml-init and connect your arguments before initializing YOLO.
# TensorBoard: Start with 'tensorboard --logdir runs/detect/train', view at http://localhost:6006/
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# /home/garrett/.local/lib/python3.10/site-packages/torch/nn/modules/conv.py:456: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:919.)
#   return F.conv2d(input, weight, bias, self.stride,
# AMP: checks passed ✅
# train: Scanning /home/garrett/Desktop/Workspace/NSIN_Sm_24/Model Optimization/datasets/RGB_and_IR/train/labels.cache... 21422 images, 5527 backgrounds, 0 corrupt: 100%|██████████| 21422/21422 [00:00<?, ?it/s]
# train: WARNING ⚠️ /home/garrett/Desktop/Workspace/NSIN_Sm_24/Model Optimization/datasets/RGB_and_IR/train/images/FLIR_05639_jpeg_jpg.rf.0930237992542a48f33862d046beed7e.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/garrett/Desktop/Workspace/NSIN_Sm_24/Model Optimization/datasets/RGB_and_IR/train/images/FLIR_05639_jpeg_jpg.rf.f2f69a5c4f4b0b9a6e26742f9f53bf8f.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/garrett/Desktop/Workspace/NSIN_Sm_24/Model Optimization/datasets/RGB_and_IR/train/images/FLIR_09055_jpeg_jpg.rf.3f65025a39739dccbf1693155c2d64f1.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/garrett/Desktop/Workspace/NSIN_Sm_24/Model Optimization/datasets/RGB_and_IR/train/images/FLIR_09055_jpeg_jpg.rf.fa5edf3ad3223329a75781ef7e7c770a.jpg: 1 duplicate labels removed
# val: Scanning /home/garrett/Desktop/Workspace/NSIN_Sm_24/Model Optimization/datasets/RGB_and_IR/valid/labels.cache... 2720 images, 744 backgrounds, 0 corrupt: 100%|██████████| 2720/2720 [00:00<?, ?it/s]
# optimizer: AdamW(lr=0.01, momentum=0.937) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# TensorBoard: model graph visualization added ✅
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to runs/detect/train
# Starting training for 30 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#   0%|          | 0/1339 [00:00<?, ?it/s]/home/garrett/.local/lib/python3.10/site-packages/torch/nn/modules/conv.py:456: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:919.)
#   return F.conv2d(input, weight, bias, self.stride,
#        1/30      2.71G      2.002      1.782       1.46         54        640: 100%|██████████| 1339/1339 [01:18<00:00, 17.00it/s]
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/30      2.46G      1.947      1.588      1.454         31        640: 100%|██████████| 1339/1339 [01:19<00:00, 16.88it/s]
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/30      2.45G      1.883      1.475      1.409         31        640: 100%|██████████| 1339/1339 [01:26<00:00, 15.57it/s]
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/30      2.48G       1.84      1.393      1.381         44        640: 100%|██████████| 1339/1339 [01:27<00:00, 15.32it/s]
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/30      2.48G      1.791      1.316      1.357         36        640: 100%|██████████| 1339/1339 [01:28<00:00, 15.16it/s]
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/30      2.45G      1.762      1.273      1.331         68        640: 100%|██████████| 1339/1339 [01:31<00:00, 14.65it/s]
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/30      2.46G      1.737      1.224      1.323         46        640: 100%|██████████| 1339/1339 [01:30<00:00, 14.79it/s]
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/30      2.59G      1.715      1.199      1.309         23        640: 100%|██████████| 1339/1339 [01:30<00:00, 14.76it/s]
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/30      2.62G      1.693      1.165      1.298         43        640: 100%|██████████| 1339/1339 [01:30<00:00, 14.74it/s]
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/30      2.32G      1.683      1.159      1.287         56        640: 100%|██████████| 1339/1339 [01:31<00:00, 14.69it/s]
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/30      2.45G      1.651      1.118      1.274         34        640: 100%|██████████| 1339/1339 [01:33<00:00, 14.35it/s]
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/30      2.48G       1.64        1.1      1.263         20        640: 100%|██████████| 1339/1339 [01:34<00:00, 14.20it/s]
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/30      2.48G      1.623      1.085      1.258         64        640: 100%|██████████| 1339/1339 [01:32<00:00, 14.55it/s]
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/30       2.5G      1.624      1.083      1.251         46        640: 100%|██████████| 1339/1339 [01:34<00:00, 14.19it/s]
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/30      2.44G      1.602      1.052      1.244         52        640: 100%|██████████| 1339/1339 [01:31<00:00, 14.67it/s]
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/30      2.48G      1.591      1.031      1.237         81        640: 100%|██████████| 1339/1339 [01:31<00:00, 14.67it/s]
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/30       2.2G      1.588      1.033       1.23         43        640:  70%|██████▉   | 936/1339 [01:04<00:25, 16.01it/s]Retrying (Retry(total=237, connect=238, read=239, redirect=240, status=240)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x717b024ba7a0>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /v2.23/tasks.get_all
#       17/30       2.2G      1.586      1.032      1.231         34        640:  73%|███████▎  | 978/1339 [01:07<00:22, 16.05it/s]Retrying (Retry(total=237, connect=237, read=240, redirect=240, status=240)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x717b6e0356f0>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /v2.23/tasks.get_all
#       17/30       2.2G      1.586      1.032       1.23         28        640:  74%|███████▍  | 990/1339 [01:08<00:25, 13.77it/s]Retrying (Retry(total=237, connect=237, read=240, redirect=240, status=240)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x717b6e037e20>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /v2.23/events.add_batch
#       17/30       2.2G      1.586      1.032      1.231         46        640:  79%|███████▉  | 1058/1339 [01:12<00:18, 15.15it/s]Retrying (Retry(total=236, connect=237, read=239, redirect=240, status=240)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x717b024bb940>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /v2.23/tasks.get_all
#       17/30       2.2G      1.589      1.032      1.231         58        640:  82%|████████▏ | 1096/1339 [01:15<00:16, 14.34it/s]Retrying (Retry(total=236, connect=236, read=240, redirect=240, status=240)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x717b6e036410>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /v2.23/tasks.get_all
#       17/30       2.2G      1.588      1.031      1.231         26        640:  83%|████████▎ | 1108/1339 [01:16<00:15, 14.69it/s]Retrying (Retry(total=236, connect=236, read=240, redirect=240, status=240)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x717b6e0826b0>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /v2.23/events.add_batch
#       17/30       2.2G      1.583      1.027      1.231         67        640:  96%|█████████▌| 1284/1339 [01:28<00:03, 14.73it/s]Retrying (Retry(total=235, connect=236, read=239, redirect=240, status=240)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x717b024b9b70>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /v2.23/tasks.get_all
#       17/30       2.2G      1.582      1.026      1.231         54        640:  99%|█████████▊| 1322/1339 [01:31<00:01, 14.74it/s]Retrying (Retry(total=235, connect=235, read=240, redirect=240, status=240)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x717b6e082bc0>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /v2.23/tasks.get_all
#       17/30       2.2G      1.581      1.025       1.23         55        640: 100%|█████████▉| 1336/1339 [01:32<00:00, 16.37it/s]Retrying (Retry(total=235, connect=235, read=240, redirect=240, status=240)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x717b6dffd120>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /v2.23/events.add_batch
#       17/30      2.48G      1.581      1.025       1.23         51        640: 100%|██████████| 1339/1339 [01:32<00:00, 14.48it/s]
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/30      2.22G      1.579       1.02      1.226         46        640:   9%|▉         | 118/1339 [00:08<01:22, 14.76it/s]Retrying (Retry(total=237, connect=237, read=240, redirect=240, status=240)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x717b6e0358d0>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /v2.23/events.add_batch
#       18/30      2.22G      1.574      1.008      1.236         52        640:  17%|█▋        | 230/1339 [00:16<01:14, 14.84it/s]Retrying (Retry(total=236, connect=236, read=240, redirect=240, status=240)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x717b6e036890>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /v2.23/events.add_batch
#       18/30      2.22G       1.57      1.011      1.232         44        640:  29%|██▉       | 392/1339 [00:28<01:08, 13.88it/s]Retrying (Retry(total=234, connect=235, read=239, redirect=240, status=240)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x717b024b8ac0>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /v2.23/tasks.get_all
#       18/30      2.22G      1.565      1.007      1.229         34        640:  32%|███▏      | 430/1339 [00:30<01:04, 14.13it/s]Retrying (Retry(total=234, connect=234, read=240, redirect=240, status=240)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x717b6dffd3c0>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /v2.23/tasks.get_all
#       18/30      2.22G      1.564      1.007      1.228         34        640:  33%|███▎      | 442/1339 [00:31<00:58, 15.23it/s]Retrying (Retry(total=234, connect=234, read=240, redirect=240, status=240)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x717b6dffd210>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /v2.23/events.add_batch
#       18/30      2.22G      1.564      1.006      1.229         46        640:  34%|███▍      | 452/1339 [00:32<00:59, 14.95it/s]Retrying (Retry(total=235, connect=235, read=240, redirect=240, status=240)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x717b6e034f10>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /v2.23/events.add_batch
#       18/30      2.22G      1.563      1.001      1.224         52        640:  68%|██████▊   | 912/1339 [01:04<00:30, 14.05it/s]Retrying (Retry(total=234, connect=234, read=240, redirect=240, status=240)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x717b6e082710>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /v2.23/events.add_batch
#       18/30      2.22G      1.566      1.005      1.222         74        640:  98%|█████████▊| 1308/1339 [01:32<00:02, 15.41it/s]Retrying (Retry(total=233, connect=234, read=239, redirect=240, status=240)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x717b024b9f60>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /v2.23/tasks.get_all
#       18/30      2.51G      1.565      1.005      1.222         44        640: 100%|██████████| 1339/1339 [01:34<00:00, 14.18it/s]
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/30      2.09G      1.568     0.9231      1.174         44        640:   0%|          | 2/1339 [00:00<01:42, 13.09it/s]Retrying (Retry(total=233, connect=233, read=240, redirect=240, status=240)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x717b6e035b70>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /v2.23/tasks.get_all
#       19/30      2.09G      1.553      0.981      1.221         59        640:   1%|          | 14/1339 [00:00<01:29, 14.75it/s]Retrying (Retry(total=233, connect=233, read=240, redirect=240, status=240)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x717b6e035900>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /v2.23/events.add_batch
#       19/30      2.16G      1.551          1      1.215         42        640:  38%|███▊      | 504/1339 [00:33<00:55, 14.96it/s]Retrying (Retry(total=233, connect=233, read=240, redirect=240, status=240)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x717b6e0833a0>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /v2.23/events.add_batch
#       19/30      2.45G      1.554     0.9983      1.218         68        640: 100%|██████████| 1339/1339 [01:33<00:00, 14.28it/s]
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/30       2.2G      1.548     0.9915      1.212         35        640:  28%|██▊       | 374/1339 [00:23<01:03, 15.27it/s]Retrying (Retry(total=232, connect=233, read=239, redirect=240, status=240)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x717ae465e9e0>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /v2.23/tasks.get_all
#       20/30       2.2G       1.55     0.9903      1.211         64        640:  31%|███       | 416/1339 [00:26<00:54, 16.83it/s]Retrying (Retry(total=232, connect=232, read=240, redirect=240, status=240)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x717b6e081d80>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /v2.23/tasks.get_all
#       20/30       2.2G      1.549     0.9893      1.212         33        640:  32%|███▏      | 430/1339 [00:27<01:00, 15.09it/s]Retrying (Retry(total=232, connect=232, read=240, redirect=240, status=240)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x717b6e082f50>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /v2.23/events.add_batch
#       20/30       2.2G      1.544     0.9836      1.217         51        640:  66%|██████▋   | 888/1339 [00:59<00:33, 13.52it/s]Retrying (Retry(total=232, connect=232, read=240, redirect=240, status=240)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x717b6e083400>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /v2.23/events.add_batch
#       20/30      2.48G      1.543     0.9833      1.214         18        640: 100%|██████████| 1339/1339 [01:30<00:00, 14.85it/s]
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/30       2.2G      1.513     0.9197      1.225         21        640:  57%|█████▋    | 761/1339 [00:53<00:40, 14.28it/s]Retrying (Retry(total=231, connect=232, read=239, redirect=240, status=240)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x717b024ba0b0>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /v2.23/tasks.get_all
#       21/30       2.2G      1.515     0.9214      1.225         25        640:  60%|█████▉    | 799/1339 [00:55<00:37, 14.48it/s]Retrying (Retry(total=231, connect=231, read=240, redirect=240, status=240)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x717b6e0810c0>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /v2.23/tasks.get_all
#       21/30       2.2G      1.514     0.9208      1.224         40        640:  61%|██████    | 811/1339 [00:56<00:35, 14.93it/s]Retrying (Retry(total=231, connect=231, read=240, redirect=240, status=240)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x717b6e080730>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /v2.23/events.add_batch
#       21/30       2.2G      1.509     0.9139      1.223         34        640:  99%|█████████▊| 1319/1339 [01:29<00:01, 14.25it/s]Retrying (Retry(total=231, connect=231, read=240, redirect=240, status=240)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x717b6e0818d0>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /v2.23/events.add_batch
#       21/30      2.48G      1.508     0.9141      1.223         17        640: 100%|██████████| 1339/1339 [01:30<00:00, 14.85it/s]
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/30      2.18G      1.484     0.8941      1.212         21        640:  90%|████████▉ | 1202/1339 [01:22<00:08, 15.23it/s]Retrying (Retry(total=230, connect=231, read=239, redirect=240, status=240)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x717b70ed85b0>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /v2.23/tasks.get_all
#       22/30      2.18G      1.485     0.8944      1.211         24        640:  92%|█████████▏| 1238/1339 [01:25<00:07, 13.17it/s]Retrying (Retry(total=230, connect=230, read=240, redirect=240, status=240)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x717b6e0811b0>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /v2.23/tasks.get_all
#       22/30      2.18G      1.484     0.8945      1.211         42        640:  93%|█████████▎| 1250/1339 [01:26<00:06, 13.19it/s]Retrying (Retry(total=230, connect=230, read=240, redirect=240, status=240)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x717b6e083460>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /v2.23/events.add_batch
#       22/30      2.46G      1.488     0.8958      1.211         25        640: 100%|██████████| 1339/1339 [01:32<00:00, 14.47it/s]
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/30      2.17G      1.468     0.8802      1.206         30        640:  30%|██▉       | 398/1339 [00:25<00:58, 16.22it/s]Retrying (Retry(total=230, connect=230, read=240, redirect=240, status=240)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x717b6e082470>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /v2.23/events.add_batch
#       23/30      2.46G      1.473     0.8803      1.208         23        640: 100%|██████████| 1339/1339 [01:31<00:00, 14.70it/s]
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/30       2.2G      1.455     0.8641      1.202         27        640:  21%|██        | 282/1339 [00:18<01:09, 15.23it/s]Retrying (Retry(total=229, connect=230, read=239, redirect=240, status=240)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x717ae465ce80>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /v2.23/tasks.get_all
#       24/30       2.2G      1.457      0.867      1.199         54        640:  24%|██▍       | 320/1339 [00:21<01:11, 14.17it/s]Retrying (Retry(total=229, connect=229, read=240, redirect=240, status=240)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x717b6e083220>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /v2.23/tasks.get_all
#       24/30       2.2G      1.457      0.869        1.2         28        640:  25%|██▍       | 334/1339 [00:22<01:05, 15.36it/s]Retrying (Retry(total=229, connect=229, read=240, redirect=240, status=240)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x717b6e082380>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /v2.23/events.add_batch
#       24/30       2.2G      1.461     0.8662        1.2         28        640:  59%|█████▊    | 786/1339 [00:54<00:39, 14.02it/s]Retrying (Retry(total=229, connect=229, read=240, redirect=240, status=240)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x717b6e081b70>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /v2.23/events.add_batch
#       24/30      2.48G       1.46      0.864        1.2         37        640: 100%|██████████| 1339/1339 [01:28<00:00, 15.06it/s]
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/30       2.2G      1.451     0.8493      1.191         35        640:  56%|█████▋    | 756/1339 [00:49<00:45, 12.95it/s]Retrying (Retry(total=228, connect=229, read=239, redirect=240, status=240)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x717b024ba110>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /v2.23/tasks.get_all
#       25/30       2.2G      1.451     0.8502      1.191         23        640:  60%|█████▉    | 798/1339 [00:52<00:38, 14.12it/s]Retrying (Retry(total=228, connect=228, read=240, redirect=240, status=240)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x717b6e083ac0>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /v2.23/tasks.get_all
#       25/30       2.2G      1.451       0.85      1.191         40        640:  60%|██████    | 810/1339 [00:53<00:34, 15.13it/s]Retrying (Retry(total=228, connect=228, read=240, redirect=240, status=240)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x717b6e0827d0>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /v2.23/events.add_batch
#       25/30       2.2G      1.451     0.8535      1.192         44        640:  98%|█████████▊| 1314/1339 [01:25<00:01, 16.27it/s]Retrying (Retry(total=228, connect=228, read=240, redirect=240, status=240)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x717b6e083c70>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /v2.23/events.add_batch
#       25/30      2.48G       1.45     0.8535      1.192         26        640: 100%|██████████| 1339/1339 [01:27<00:00, 15.38it/s]
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/30      2.17G       1.44     0.8424      1.187         31        640:  91%|█████████▏| 1222/1339 [01:22<00:08, 14.13it/s]Retrying (Retry(total=227, connect=228, read=239, redirect=240, status=240)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x717b70ed8fa0>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /v2.23/tasks.get_all
#       26/30      2.17G      1.439     0.8419      1.187         29        640:  94%|█████████▍| 1264/1339 [01:24<00:04, 15.16it/s]Retrying (Retry(total=227, connect=227, read=240, redirect=240, status=240)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x717b6e081bd0>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /v2.23/tasks.get_all
#       26/30      2.17G      1.438     0.8414      1.187         29        640:  95%|█████████▌| 1276/1339 [01:25<00:04, 14.01it/s]Retrying (Retry(total=227, connect=227, read=240, redirect=240, status=240)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x717b6e0828f0>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /v2.23/events.add_batch
#       26/30      2.46G      1.439     0.8427      1.187         27        640: 100%|██████████| 1339/1339 [01:29<00:00, 14.88it/s]
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/30      2.17G      1.435     0.8357      1.183         31        640:  32%|███▏      | 426/1339 [00:28<01:15, 12.15it/s]Retrying (Retry(total=227, connect=227, read=240, redirect=240, status=240)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x717b6e081900>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /v2.23/events.add_batch
#       27/30      2.46G      1.425     0.8324      1.182         27        640: 100%|██████████| 1339/1339 [01:28<00:00, 15.10it/s]
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/30       2.2G      1.424     0.8243      1.175         45        640:  27%|██▋       | 360/1339 [00:23<00:57, 16.96it/s]Retrying (Retry(total=226, connect=227, read=239, redirect=240, status=240)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x717b023f3fa0>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /v2.23/tasks.get_all
#       28/30       2.2G      1.425     0.8205      1.176         24        640:  30%|███       | 406/1339 [00:25<00:56, 16.52it/s]Retrying (Retry(total=226, connect=226, read=240, redirect=240, status=240)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x717b6e0835b0>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /v2.23/tasks.get_all
#       28/30       2.2G      1.425     0.8213      1.177         32        640:  31%|███▏      | 420/1339 [00:26<00:53, 17.03it/s]Retrying (Retry(total=226, connect=226, read=240, redirect=240, status=240)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x717b6e0804f0>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /v2.23/events.add_batch
#       28/30       2.2G      1.421      0.818      1.179         49        640:  68%|██████▊   | 912/1339 [00:59<00:32, 12.95it/s]Retrying (Retry(total=226, connect=226, read=240, redirect=240, status=240)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x717b6e0836d0>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /v2.23/events.add_batch
#       28/30      2.48G      1.414     0.8146      1.173         55        640: 100%|██████████| 1339/1339 [01:29<00:00, 14.89it/s]
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/30       2.2G        1.4     0.8118      1.164         26        640:  62%|██████▏   | 825/1339 [00:53<00:37, 13.82it/s]Retrying (Retry(total=225, connect=226, read=239, redirect=240, status=240)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x717b022ce890>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /v2.23/tasks.get_all
#       29/30       2.2G        1.4     0.8119      1.164         21        640:  65%|██████▍   | 865/1339 [00:55<00:30, 15.50it/s]Retrying (Retry(total=225, connect=225, read=240, redirect=240, status=240)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x717b6e0832b0>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /v2.23/tasks.get_all
#       29/30       2.2G      1.399     0.8118      1.164         33        640:  65%|██████▌   | 877/1339 [00:56<00:30, 15.00it/s]Retrying (Retry(total=225, connect=225, read=240, redirect=240, status=240)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x717b6e083d30>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /v2.23/events.add_batch
#       29/30      2.48G      1.404     0.8135      1.167         21        640: 100%|██████████| 1339/1339 [01:27<00:00, 15.39it/s]
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/30       2.1G      1.401     0.8099      1.156         35        640:   2%|▏         | 32/1339 [00:02<01:24, 15.45it/s]Retrying (Retry(total=225, connect=225, read=240, redirect=240, status=240)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x717b6e081270>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /v2.23/events.add_batch
#       30/30      2.18G      1.391     0.8033      1.163         22        640:  95%|█████████▌| 1276/1339 [01:26<00:04, 15.09it/s]Retrying (Retry(total=224, connect=225, read=239, redirect=240, status=240)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x717b70ed8760>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /v2.23/tasks.get_all
#       30/30      2.18G       1.39     0.8031      1.163         42        640:  98%|█████████▊| 1318/1339 [01:28<00:01, 15.60it/s]Retrying (Retry(total=224, connect=224, read=240, redirect=240, status=240)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x717b6e0835e0>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /v2.23/tasks.get_all
#       30/30      2.18G       1.39     0.8025      1.163         20        640:  99%|█████████▉| 1332/1339 [01:29<00:00, 15.70it/s]Retrying (Retry(total=224, connect=224, read=240, redirect=240, status=240)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x717b6e080bb0>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /v2.23/events.add_batch
#       30/30      2.46G       1.39     0.8026      1.163         35        640: 100%|██████████| 1339/1339 [01:30<00:00, 14.87it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):   0%|          | 0/85 [00:00<?, ?it/s]/home/garrett/.local/lib/python3.10/site-packages/torch/nn/modules/conv.py:456: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:919.)
#   return F.conv2d(input, weight, bias, self.stride,
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 85/85 [00:06<00:00, 13.85it/s]
#                    all       2720       6329      0.858      0.763      0.861      0.477
#
# 30 epochs completed in 0.754 hours.
# Optimizer stripped from runs/detect/train/weights/last.pt, 6.2MB
# Optimizer stripped from runs/detect/train/weights/best.pt, 6.2MB
#
# Validating runs/detect/train/weights/best.pt...
# Ultralytics YOLOv8.2.32 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (NVIDIA RTX 4000 Ada Generation Laptop GPU, 11911MiB)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
# /home/garrett/.local/lib/python3.10/site-packages/torch/nn/modules/conv.py:456: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:919.)
#   return F.conv2d(input, weight, bias, self.stride,
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 85/85 [00:04<00:00, 17.26it/s]
#                    all       2720       6329      0.858      0.762      0.861      0.477
# Speed: 0.1ms preprocess, 0.6ms inference, 0.0ms loss, 0.3ms postprocess per image
# Retrying (Retry(total=237, connect=237, read=240, redirect=240, status=240)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x717b70e84b50>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /v2.23/tasks.get_by_id
# Retrying (Retry(total=236, connect=236, read=240, redirect=240, status=240)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x717b70e85b40>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /v2.23/tasks.get_by_id
# Retrying (Retry(total=224, connect=224, read=240, redirect=240, status=240)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x717b6e0807f0>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /v2.23/events.add_batch
# Retrying (Retry(total=235, connect=235, read=240, redirect=240, status=240)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x717b70e86d10>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /v2.23/tasks.get_by_id
# Retrying (Retry(total=234, connect=234, read=240, redirect=240, status=240)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x717b3b46b2e0>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /v2.23/tasks.get_by_id
# Retrying (Retry(total=223, connect=224, read=239, redirect=240, status=240)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x717b70ed85e0>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /v2.23/tasks.get_all
# Retrying (Retry(total=223, connect=223, read=240, redirect=240, status=240)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x717b6e0814b0>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /v2.23/tasks.get_all
# Retrying (Retry(total=223, connect=223, read=240, redirect=240, status=240)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x717b6e0808b0>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /v2.23/events.add_batch
# Retrying (Retry(total=233, connect=233, read=240, redirect=240, status=240)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x717b3b46abf0>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /v2.23/tasks.get_by_id
# Retrying (Retry(total=223, connect=223, read=240, redirect=240, status=240)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x717b6e080d90>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /v2.23/events.add_batch
# Retrying (Retry(total=222, connect=223, read=239, redirect=240, status=240)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x717b3b46a650>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /v2.23/tasks.get_all
# Retrying (Retry(total=222, connect=222, read=240, redirect=240, status=240)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x717b6e081600>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /v2.23/tasks.get_all
# Retrying (Retry(total=222, connect=222, read=240, redirect=240, status=240)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x717b6e083e50>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /v2.23/events.add_batch
# Retrying (Retry(total=232, connect=232, read=240, redirect=240, status=240)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x717b3b46bd00>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /v2.23/tasks.get_by_id
# Retrying (Retry(total=222, connect=222, read=240, redirect=240, status=240)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x717b6e082260>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /v2.23/events.add_batch
# Retrying (Retry(total=221, connect=222, read=239, redirect=240, status=240)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x717b3b46a5f0>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /v2.23/tasks.get_all
# Retrying (Retry(total=221, connect=221, read=240, redirect=240, status=240)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x717b6e082a40>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /v2.23/tasks.get_all
# Retrying (Retry(total=221, connect=221, read=240, redirect=240, status=240)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x717bd4a3c130>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /v2.23/events.add_batch
# Retrying (Retry(total=231, connect=231, read=240, redirect=240, status=240)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x717b3b46b9d0>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /v2.23/tasks.get_by_id
# Retrying (Retry(total=221, connect=221, read=240, redirect=240, status=240)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x717bd4a3c3a0>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /v2.23/events.add_batch
# Retrying (Retry(total=220, connect=221, read=239, redirect=240, status=240)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x717b3b46b970>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /v2.23/tasks.get_all
# Retrying (Retry(total=220, connect=220, read=240, redirect=240, status=240)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x717bd4a3c760>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /v2.23/tasks.get_all
# Retrying (Retry(total=220, connect=220, read=240, redirect=240, status=240)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x717bd4a3c220>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /v2.23/events.add_batch
# Retrying (Retry(total=230, connect=230, read=240, redirect=240, status=240)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x717b3b46a710>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /v2.23/tasks.get_by_id
# Retrying (Retry(total=220, connect=220, read=240, redirect=240, status=240)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x717bd4a3cbe0>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /v2.23/events.add_batch
# Retrying (Retry(total=219, connect=220, read=239, redirect=240, status=240)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x717b3b46a890>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /v2.23/tasks.get_all
# ...
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/30      2.48G      1.193     0.9135      1.169         18        640: 100%|██████████| 1339/1339 [01:30<00:00, 14.84it/s]
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/30      2.48G      1.178      0.893      1.157         25        640: 100%|██████████| 1339/1339 [01:39<00:00, 13.41it/s]
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/30      2.46G      1.159      0.874      1.149         23        640: 100%|██████████| 1339/1339 [01:37<00:00, 13.67it/s]
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/30      2.44G      1.153     0.8599      1.145         37        640: 100%|██████████| 1339/1339 [01:36<00:00, 13.86it/s]
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/30      2.48G      1.146      0.851      1.137         26        640: 100%|██████████| 1339/1339 [01:37<00:00, 13.70it/s]
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/30      2.46G      1.134     0.8401      1.131         28        640: 100%|██████████| 1339/1339 [01:35<00:00, 13.96it/s]
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/30      2.47G      1.125     0.8278      1.126         27        640: 100%|██████████| 1339/1339 [01:38<00:00, 13.59it/s]
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/30      2.44G      1.115     0.8147      1.117         57        640: 100%|██████████| 1339/1339 [01:35<00:00, 14.04it/s]
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/30      2.48G      1.107     0.8049      1.111         21        640: 100%|██████████| 1339/1339 [01:39<00:00, 13.47it/s]
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/30      2.48G      1.102     0.7992       1.11         35        640: 100%|██████████| 1339/1339 [01:27<00:00, 15.36it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):   0%|          | 0/85 [00:00<?, ?it/s]/home/garrett/.local/lib/python3.10/site-packages/torch/nn/modules/conv.py:456: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:919.)
#   return F.conv2d(input, weight, bias, self.stride,
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 85/85 [00:08<00:00,  9.51it/s]
#                    all       2720       6329      0.858      0.769      0.863      0.485
#
# 30 epochs completed in 0.815 hours.
# Optimizer stripped from runs/detect/train77/weights/last.pt, 6.2MB
# Optimizer stripped from runs/detect/train77/weights/best.pt, 6.2MB
#
# Validating runs/detect/train77/weights/best.pt...
# Ultralytics YOLOv8.2.32 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (NVIDIA RTX 4000 Ada Generation Laptop GPU, 11911MiB)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
# /home/garrett/.local/lib/python3.10/site-packages/torch/nn/modules/conv.py:456: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:919.)
#   return F.conv2d(input, weight, bias, self.stride,
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 85/85 [00:06<00:00, 12.27it/s]
#                    all       2720       6329      0.858      0.769      0.863      0.485
# Speed: 0.1ms preprocess, 0.6ms inference, 0.0ms loss, 0.5ms postprocess per image
# 💡 Learn more at https://docs.ultralytics.com/modes/train
# Saved runs/detect/tune/tune_scatter_plots.png
# Saved runs/detect/tune/tune_fitness.png
#
# Tuner: 77/300 iterations complete ✅ (236944.28s)
# Tuner: Results saved to runs/detect/tune
# Tuner: Best fitness=0.52936 observed at iteration 70
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.86495, 'metrics/recall(B)': 0.76947, 'metrics/mAP50(B)': 0.86657, 'metrics/mAP50-95(B)': 0.49189, 'val/box_loss': 0.89194, 'val/cls_loss': 0.69237, 'val/dfl_loss': 1.19373, 'fitness': 0.52936}
# Tuner: Best fitness model is runs/detect/train70
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs/detect/tune/best_hyperparameters.yaml'
#
# lr0: 0.00566
# lrf: 0.01181
# momentum: 0.84807
# weight_decay: 0.00072
# warmup_epochs: 2.14676
# warmup_momentum: 0.89766
# box: 4.68835
# cls: 0.41993
# dfl: 1.68975
# hsv_h: 0.02178
# hsv_s: 0.31623
# hsv_v: 0.39679
# degrees: 0.0
# translate: 0.07479
# scale: 0.35502
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.53298
# bgr: 0.0
# mosaic: 0.81277
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 78/300 with hyperparameters: {'lr0': 0.00597, 'lrf': 0.01282, 'momentum': 0.86633, 'weight_decay': 0.00068, 'warmup_epochs': 2.26922, 'warmup_momentum': 0.86945, 'box': 6.0296, 'cls': 0.54954, 'dfl': 1.56275, 'hsv_h': 0.01794, 'hsv_s': 0.35668, 'hsv_v': 0.44483, 'degrees': 0.0, 'translate': 0.07906, 'scale': 0.3553, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.52263, 'bgr': 0.0, 'mosaic': 0.8669, 'mixup': 0.0, 'copy_paste': 0.0}
# New https://pypi.org/project/ultralytics/8.2.38 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.32 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (NVIDIA RTX 4000 Ada Generation Laptop GPU, 11911MiB)
# engine/trainer: task=detect, mode=train, model=yolov8n.pt, data=./datasets/RGB_and_IR/data.yaml, epochs=30, time=None, patience=100, batch=16, imgsz=640, save=False, save_period=-1, cache=False, device=None, workers=8, project=None, name=train78, exist_ok=False, pretrained=True, optimizer=AdamW, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=False, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=False, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.00597, lrf=0.01282, momentum=0.86633, weight_decay=0.00068, warmup_epochs=2.26922, warmup_momentum=0.86945, warmup_bias_lr=0.1, box=6.0296, cls=0.54954, dfl=1.56275, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.01794, hsv_s=0.35668, hsv_v=0.44483, degrees=0.0, translate=0.07906, scale=0.3553, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.52263, bgr=0.0, mosaic=0.8669, mixup=0.0, copy_paste=0.0, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/train78
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    751507  ultralytics.nn.modules.head.Detect           [1, [64, 128, 256]]
# Model summary: 225 layers, 3011043 parameters, 3011027 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# ClearML Task: created new task id=b08fdfa91c6843f2bd6c8142cf3757e6
# 2024-06-21 04:09:27,651 - clearml.Task - INFO - No repository found, storing script code instead
# ClearML results page: https://app.clear.ml/projects/1bf4b4ada375438ebdd6797d9048296d/experiments/b08fdfa91c6843f2bd6c8142cf3757e6/output/log
# ClearML Initialized a new task. If you want to run remotely, please add clearml-init and connect your arguments before initializing YOLO.
# TensorBoard: Start with 'tensorboard --logdir runs/detect/train78', view at http://localhost:6006/
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# /home/garrett/.local/lib/python3.10/site-packages/torch/nn/modules/conv.py:456: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:919.)
#   return F.conv2d(input, weight, bias, self.stride,
# AMP: checks passed ✅
# train: Scanning /home/garrett/Desktop/Workspace/NSIN_Sm_24/Model Optimization/datasets/RGB_and_IR/train/labels.cache... 21422 images, 5527 backgrounds, 0 corrupt: 100%|██████████| 21422/21422 [00:00<?, ?it/s]
# train: WARNING ⚠️ /home/garrett/Desktop/Workspace/NSIN_Sm_24/Model Optimization/datasets/RGB_and_IR/train/images/FLIR_05639_jpeg_jpg.rf.0930237992542a48f33862d046beed7e.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/garrett/Desktop/Workspace/NSIN_Sm_24/Model Optimization/datasets/RGB_and_IR/train/images/FLIR_05639_jpeg_jpg.rf.f2f69a5c4f4b0b9a6e26742f9f53bf8f.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/garrett/Desktop/Workspace/NSIN_Sm_24/Model Optimization/datasets/RGB_and_IR/train/images/FLIR_09055_jpeg_jpg.rf.3f65025a39739dccbf1693155c2d64f1.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/garrett/Desktop/Workspace/NSIN_Sm_24/Model Optimization/datasets/RGB_and_IR/train/images/FLIR_09055_jpeg_jpg.rf.fa5edf3ad3223329a75781ef7e7c770a.jpg: 1 duplicate labels removed
# val: Scanning /home/garrett/Desktop/Workspace/NSIN_Sm_24/Model Optimization/datasets/RGB_and_IR/valid/labels.cache... 2720 images, 744 backgrounds, 0 corrupt: 100%|██████████| 2720/2720 [00:00<?, ?it/s]
# optimizer: AdamW(lr=0.00597, momentum=0.86633) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.00068), 63 bias(decay=0.0)
# TensorBoard: model graph visualization added ✅
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to runs/detect/train78
# Starting training for 30 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#   0%|          | 0/1339 [00:00<?, ?it/s]/home/garrett/.local/lib/python3.10/site-packages/torch/nn/modules/conv.py:456: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:919.)
#   return F.conv2d(input, weight, bias, self.stride,
#        1/30      2.48G      1.579      1.909      1.509         45        640: 100%|██████████| 1339/1339 [01:36<00:00, 13.82it/s]
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/30      2.56G      1.531      1.705      1.501         19        640: 100%|██████████| 1339/1339 [01:39<00:00, 13.48it/s]
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/30      2.44G      1.477       1.55      1.455         47        640: 100%|██████████| 1339/1339 [01:35<00:00, 14.05it/s]
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/30      2.48G      1.431      1.461      1.414         30        640: 100%|██████████| 1339/1339 [01:38<00:00, 13.56it/s]
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/30      2.51G      1.389      1.361      1.382         18        640: 100%|██████████| 1339/1339 [01:36<00:00, 13.84it/s]
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/30      2.47G      1.376      1.334      1.378         28        640: 100%|██████████| 1339/1339 [01:37<00:00, 13.79it/s]
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/30      2.45G      1.358      1.302      1.362         37        640: 100%|██████████| 1339/1339 [01:42<00:00, 13.12it/s]
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/30      2.46G      1.344      1.261      1.343         35        640: 100%|██████████| 1339/1339 [01:36<00:00, 13.81it/s]
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/30      2.48G       1.33      1.231      1.335         27        640: 100%|██████████| 1339/1339 [01:44<00:00, 12.80it/s]
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/30      2.46G      1.316      1.215      1.323         51        640: 100%|██████████| 1339/1339 [01:38<00:00, 13.55it/s]
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/30      2.57G      1.301      1.192      1.314         37        640: 100%|██████████| 1339/1339 [01:35<00:00, 14.08it/s]
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/30      2.45G      1.291      1.168      1.301         28        640: 100%|██████████| 1339/1339 [01:41<00:00, 13.21it/s]
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/30       2.1G      1.274      1.073       1.18         58        640:   0%|          | 0/1339 [00:00<?, ?it/s]
